# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-5,5,100)
y1 = x*np.sin(x**2)+np.exp(-x**2/2)
y2 = np.floor(x)
y3 = np.cos(x)+np.exp(-x**2/2)
plt.plot(x,y1,'r--',label='$y_1$')
plt.plot(x,y2,'m-',label='$y_2$')
plt.plot(x,y3,'y-.',label='$y_3$')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-2,2,100)
y1 = np.sin(np.abs(x))
y2 = np.floor(x)
y3 = np.cos(x)+np.exp(-x**2/2)
plt.plot(x,y1,'r--',label='$y_1$')
plt.plot(x,y2,'m-',label='$y_2$')
plt.plot(x,y3,'y-.',label='$y_3$')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-1,1,100)
y1 = np.exp(x)
y2 = np.floor(x)
y3 = np.cos(x)
plt.plot(x,y1,'r--',label='$y_1$')
plt.plot(x,y2,'m-',label='$y_2$')
plt.plot(x,y3,'y-.',label='$y_3$')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.linspace(-5,5,100)
plt.figure(figsize=(6,4))

# first graph
plt.subplot(2,2,1)
plt.plot(t,np.sin(t))

# second graph 
plt.subplot(2,2,2)
plt.plot(t,np.sin(2*t), 'r:.')

# third graph 
plt.subplot(2,2,3)
plt.plot(t,np.sin(3*t), 'g-.')

# fourth graph
plt.subplot(2,2,4)
plt.plot(t,np.sin(4*t), 'b--')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.linspace(-5,5,100)
plt.figure(figsize=(6,4))

# first graph
plt.subplot(2,2,1)
plt.plot(t,np.tan(t))

# second graph 
plt.subplot(2,2,2)
plt.plot(t,np.tan(2*t), 'r:.')

# third graph 
plt.subplot(2,2,3)
plt.plot(t,np.tan(3*t), 'g-.')

# fourth graph
plt.subplot(2,2,4)
plt.plot(t,np.tan(4*t), 'b--')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.linspace(-5,5,100)
plt.figure(figsize=(6,4))

# first graph
plt.subplot(2,2,1)
plt.plot(t,np.abs(t))

# second graph 
plt.subplot(2,2,2)
plt.plot(t,np.abs(2*t), 'r:.')

# third graph 
plt.subplot(2,2,3)
plt.plot(t,np.abs(3*t), 'g-.')

# fourth graph
plt.subplot(2,2,4)
plt.plot(t,np.abs(4*t), 'b--')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.linspace(-5,5,100)
plt.figure(figsize=(6,4))

# first graph
plt.subplot(2,2,1)
plt.plot(t,np.floor(t))

# second graph 
plt.subplot(2,2,2)
plt.plot(t,np.floor(2*t), 'r:.')

# third graph 
plt.subplot(2,2,3)
plt.plot(t,np.floor(3*t), 'g-.')

# fourth graph
plt.subplot(2,2,4)
plt.plot(t,np.floor(4*t), 'b--')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.linspace(-5,5,100)
plt.figure(figsize=(6,4))

# first graph
plt.subplot(2,2,1)
plt.plot(t,1/np.sin(t))

# second graph 
plt.subplot(2,2,2)
plt.plot(t,1/np.sin(2*t), 'r:.')

# third graph 
plt.subplot(2,2,3)
plt.plot(t,1/np.sin(3*t), 'g-.')

# fourth graph
plt.subplot(2,2,4)
plt.plot(t,1/np.sin(4*t), 'b--')
plt.show()

# %%
## figure eight 
from matplotlib import pyplot as plt
import numpy as np
t = np.linspace(-4,4,200)
a = 2
x = a*np.sin(t)
y = a*np.sin(t)*np.cos(t)
plt.plot(x,y)
plt.show()
